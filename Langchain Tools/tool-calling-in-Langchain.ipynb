# %%
# %pip install \
langchain \
langchain-core \
langchain-community \
langchain-text-splitters \
langchain-openai \
langchain-ollama \
langchain-chroma \
chromadb \
faiss-cpu \
pydantic \
duckduckgo-search \
langchain-experimental \
youtube-transcript-api \
pypdf \
sentence-transformers \
tiktoken \
python-dotenv \
ipykernel
# Out:
# Requirement already satisfied: langchain in c:\Python311\Lib\site-packages (1.2.15)
# Requirement already satisfied: langchain-core in c:\Python311\Lib\site-packages (1.3.2)
# Requirement already satisfied: langchain-community in c:\Python311\Lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-text-splitters in c:\Python311\Lib\site-packages (1.1.2)
# Requirement already satisfied: langchain-openai in c:\Python311\Lib\site-packages (1.2.1)
# Requirement already satisfied: langchain-ollama in c:\Python311\Lib\site-packages (1.1.0)
# Requirement already satisfied: langchain-chroma in c:\Python311\Lib\site-packages (1.1.0)
# Requirement already satisfied: chromadb in c:\Python311\Lib\site-packages (1.5.8)
# Requirement already satisfied: faiss-cpu in c:\Python311\Lib\site-packages (1.13.2)
# Requirement already satisfied: pydantic in c:\Python311\Lib\site-packages (2.13.3)
# Requirement already satisfied: duckduckgo-search in c:\Python311\Lib\site-packages (8.1.1)
# Requirement already satisfied: langchain-experimental in c:\Python311\Lib\site-packages (0.4.1)
# Requirement already satisfied: youtube-transcript-api in c:\Python311\Lib\site-packages (1.2.4)
# Requirement already satisfied: pypdf in c:\Python311\Lib\site-packages (6.10.2)
# Requirement already satisfied: sentence-transformers in c:\Python311\Lib\site-packages (5.4.0)
# Requirement already satisfied: tiktoken in c:\Python311\Lib\site-packages (0.12.0)
# Requirement already satisfied: python-dotenv in c:\Python311\Lib\site-packages (1.0.1)
# Requirement already satisfied: ipykernel in C:\Users\akshi\AppData\Roaming\Python\Python311\site-packages (7.1.0)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.5 in c:\Python311\Lib\site-packages (from langchain) (1.1.9)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\Python311\Lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.10 in c:\Python311\Lib\site-packages (from langchain-core) (0.0.12)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\Python311\Lib\site-packages (from langchain-core) (0.7.36)
# Requirement already satisfied: packaging>=23.2.0 in c:\Python311\Lib\site-packages (from langchain-core) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\Python311\Lib\site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\Python311\Lib\site-packages (from langchain-core) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\akshi\AppData\Roaming\Python\Python311\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\Python311\Lib\site-packages (from langchain-core) (0.14.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Python311\Lib\site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in c:\Python311\Lib\site-packages (from pydantic) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Python311\Lib\site-packages (from pydantic) (0.4.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\Python311\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\Python311\Lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (4.0.2)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in c:\Python311\Lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (1.0.11)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\Python311\Lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in c:\Python311\Lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\Python311\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\Python311\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\Python311\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\Python311\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\Python311\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.33.1)
# Requirement already satisfied: zstandard>=0.23.0 in c:\Python311\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: anyio in c:\Python311\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (4.12.1)
# Requirement already satisfied: certifi in c:\Python311\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\Python311\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\Python311\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\Python311\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.16.0)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\Python311\Lib\site-packages (from langchain-community) (1.0.4)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\Python311\Lib\site-packages (from langchain-community) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\Python311\Lib\site-packages (from langchain-community) (3.13.5)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\Python311\Lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\Python311\Lib\site-packages (from langchain-community) (2.14.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\Python311\Lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\Python311\Lib\site-packages (from langchain-community) (2.3.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\Python311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\Python311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\Python311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\Python311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\Python311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\Python311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\Python311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\Python311\Lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\Python311\Lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Python311\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Python311\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.6.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\Python311\Lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\Python311\Lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in c:\Python311\Lib\site-packages (from langchain-openai) (2.32.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\Python311\Lib\site-packages (from tiktoken) (2026.4.4)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\Python311\Lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\Python311\Lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (0.14.0)
# Requirement already satisfied: sniffio in c:\Python311\Lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\Python311\Lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.67.3)
# Requirement already satisfied: ollama<1.0.0,>=0.6.1 in c:\Python311\Lib\site-packages (from langchain-ollama) (0.6.1)
# Requirement already satisfied: build>=1.0.3 in c:\Python311\Lib\site-packages (from chromadb) (1.4.4)
# Requirement already satisfied: pybase64>=1.4.1 in c:\Python311\Lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\Python311\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.30.1)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\Python311\Lib\site-packages (from chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\Python311\Lib\site-packages (from chromadb) (1.41.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\Python311\Lib\site-packages (from chromadb) (1.41.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\Python311\Lib\site-packages (from chromadb) (1.41.1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\Python311\Lib\site-packages (from chromadb) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in c:\Python311\Lib\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\Python311\Lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\Python311\Lib\site-packages (from chromadb) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in c:\Python311\Lib\site-packages (from chromadb) (1.80.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\Python311\Lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\Python311\Lib\site-packages (from chromadb) (0.24.1)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\Python311\Lib\site-packages (from chromadb) (35.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\Python311\Lib\site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: rich>=10.11.0 in c:\Python311\Lib\site-packages (from chromadb) (14.3.3)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\Python311\Lib\site-packages (from chromadb) (4.26.0)
# Requirement already satisfied: click>=8.1.8 in c:\Python311\Lib\site-packages (from duckduckgo-search) (8.3.1)
# Requirement already satisfied: primp>=0.15.0 in c:\Python311\Lib\site-packages (from duckduckgo-search) (1.1.3)
# Requirement already satisfied: lxml>=5.3.0 in c:\Python311\Lib\site-packages (from duckduckgo-search) (6.0.2)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in c:\Python311\Lib\site-packages (from youtube-transcript-api) (0.7.1)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\Python311\Lib\site-packages (from sentence-transformers) (5.5.3)
# Requirement already satisfied: huggingface-hub>=0.23.0 in c:\Python311\Lib\site-packages (from sentence-transformers) (1.9.2)
# Requirement already satisfied: torch>=1.11.0 in c:\Python311\Lib\site-packages (from sentence-transformers) (2.11.0)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\Python311\Lib\site-packages (from sentence-transformers) (1.5.0)
# Requirement already satisfied: scipy>=1.0.0 in c:\Python311\Lib\site-packages (from sentence-transformers) (1.17.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\Python311\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: filelock>=3.10.0 in c:\Python311\Lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\Python311\Lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in c:\Python311\Lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (1.4.3)
# Requirement already satisfied: comm>=0.1.1 in C:\Users\akshi\AppData\Roaming\Python\Python311\site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in C:\Users\akshi\AppData\Roaming\Python\Python311\site-packages (from ipykernel) (1.8.19)
# Requirement already satisfied: ipython>=7.23.1 in C:\Users\akshi\AppData\Roaming\Python\Python311\site-packages (from ipykernel) (9.9.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in C:\Users\akshi\AppData\Roaming\Python\Python311\site-packages (from ipykernel) (8.8.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in C:\Users\akshi\AppData\Roaming\Python\Python311\site-packages (from ipykernel) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in C:\Users\akshi\AppData\Roaming\Python\Python311\site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in C:\Users\akshi\AppData\Roaming\Python\Python311\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in C:\Users\akshi\AppData\Roaming\Python\Python311\site-packages (from ipykernel) (7.2.1)
# Requirement already satisfied: pyzmq>=25 in C:\Users\akshi\AppData\Roaming\Python\Python311\site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in C:\Users\akshi\AppData\Roaming\Python\Python311\site-packages (from ipykernel) (6.5.4)
# Requirement already satisfied: traitlets>=5.4.0 in C:\Users\akshi\AppData\Roaming\Python\Python311\site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: pyproject_hooks in c:\Python311\Lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in C:\Users\akshi\AppData\Roaming\Python\Python311\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in C:\Users\akshi\AppData\Roaming\Python\Python311\site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in C:\Users\akshi\AppData\Roaming\Python\Python311\site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in C:\Users\akshi\AppData\Roaming\Python\Python311\site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in C:\Users\akshi\AppData\Roaming\Python\Python311\site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in C:\Users\akshi\AppData\Roaming\Python\Python311\site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in C:\Users\akshi\AppData\Roaming\Python\Python311\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: wcwidth in C:\Users\akshi\AppData\Roaming\Python\Python311\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in C:\Users\akshi\AppData\Roaming\Python\Python311\site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel) (0.8.5)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\Python311\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\Python311\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\Python311\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Python311\Lib\site-packages (from jupyter-client>=8.0.0->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in C:\Users\akshi\AppData\Roaming\Python\Python311\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.5.1)
# Requirement already satisfied: six>=1.9.0 in c:\Python311\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\Python311\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in c:\Python311\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in c:\Python311\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: flatbuffers in c:\Python311\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in c:\Python311\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.6)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\Python311\Lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in c:\Python311\Lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\Python311\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.74.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.41.1 in c:\Python311\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.41.1)
# Requirement already satisfied: opentelemetry-proto==1.41.1 in c:\Python311\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.41.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.62b1 in c:\Python311\Lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.62b1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\Python311\Lib\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\Python311\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\Python311\Lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\Python311\Lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: executing>=1.2.0 in C:\Users\akshi\AppData\Roaming\Python\Python311\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in C:\Users\akshi\AppData\Roaming\Python\Python311\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (3.0.1)
# Requirement already satisfied: pure-eval in C:\Users\akshi\AppData\Roaming\Python\Python311\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (0.2.3)
# Requirement already satisfied: setuptools<82 in c:\Python311\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (65.5.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\Python311\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\Python311\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in c:\Python311\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\Python311\Lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\Python311\Lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\Python311\Lib\site-packages (from typer>=0.9.0->chromadb) (0.0.4)
# Requirement already satisfied: httptools>=0.5.0 in c:\Python311\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\Python311\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in c:\Python311\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Python311\Lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\Python311\Lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_ollama import ChatOllama
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
import requests

# %%
# tool create

@tool
def multiply(a: int, b: int) -> int:
  """Given 2 numbers a and b this tool returns their product"""
  return a * b

# %%
print(multiply.invoke({'a':3, 'b':4}))

# %%
multiply.name , multiply.description , multiply.args

# %% [markdown]
# toolbinding

# %%
llm = ChatOllama(model = 'llama3')
llm.invole('hi')

# %%
llm_with_tools = llm.bind_tools([multiply])

# %%
llm_with_tools.invoke('Hi how are you')

# %%
query = HumanMessage('can you multiply 3 with 1000')
messages = [query]
messages

# %%
result = llm_with_tools.invoke(messages)
messages.append(result)
messages

# %%
tool_result = multiply.invoke(result.tool_calls[0])
tool_result

# %%
messages.append(tool_result)
messages

# %%
llm_with_tools.invoke(messages).content

# %%
# tool create
from langchain_core.tools import InjectedToolArg
from typing import Annotated

@tool
def get_conversion_factor(base_currency: str, target_currency: str) -> float:
  """
  This function fetches the currency conversion factor between a given base currency and a target currency
  """
  url = f'https://v6.exchangerate-api.com/v6/c754eab14ffab33112e380ca/pair/{base_currency}/{target_currency}'

  response = requests.get(url)

  return response.json()

@tool
def convert(base_currency_value: int, conversion_rate: Annotated[float, InjectedToolArg]) -> float:
  """
  given a currency conversion rate this function calculates the target currency value from a given base currency value
  """

  return base_currency_value * conversion_rate

# %%
convert.args

# %%
get_conversion_factor.invoke({'base_currency':'USD','target_currency':'INR'})

# %%
convert.invoke({'base_currency_value':10, 'conversion_rate':85.16})

# %%
llm - ChatOllama(model = 'llama3')
llm_with_tools = llm.bind_tools([get_conversion_factor, convert])
messages = [HumanMessage('What is the conversion factor between INR and USD, and based on that can you convert 10 inr to usd')]
messages

# %%
ai_message = llm_with_tools.invoke(messages)
messages.append(ai_message)
ai_message.tool_calls

# %%
import json

for tool_call in ai_message.tool_calls:
  # execute the 1st tool and get the value of conversion rate
  if tool_call['name'] == 'get_conversion_factor':
    tool_message1 = get_conversion_factor.invoke(tool_call)
    # fetch this conversion rate
    conversion_rate = json.loads(tool_message1.content)['conversion_rate']
    # append this tool message to messages list
    messages.append(tool_message1)
  # execute the 2nd tool using the conversion rate from tool 1
  if tool_call['name'] == 'convert':
    # fetch the current arg
    tool_call['args']['conversion_rate'] = conversion_rate
    tool_message2 = convert.invoke(tool_call)
    messages.append(tool_message2)

# %%
messages

# %%
llm_with_tools.invoke(messages).content

# %%
from langchain.agents import initialize_agent, AgentType

# Step 5: Initialize the Agent ---
agent_executor = initialize_agent(
    tools=[get_conversion_factor, convert],
    llm=llm,
    agent=AgentType.STRUCTURED_CHAT_ZERO_SHOT_REACT_DESCRIPTION,  # using ReAct pattern
    verbose=True  # shows internal thinking
)

# %%
# --- Step 6: Run the Agent ---
user_query = "Hi how are you?"

response = agent_executor.invoke({"input": user_query})
